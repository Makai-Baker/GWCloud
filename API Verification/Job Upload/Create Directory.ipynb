# %%
import glob
import os
import shutil

catalogue = 'GWTC-2'

dirs = ['data', 'log_data_analysis', 'log_data_generation', 'log_results_page', 'result', 'results_page', 'submit']
for json_file in glob.glob(catalogue + '/*.json'):
    event = str(json_file)[:-17]
    print(event + " result file located")
    for ini_file in glob.glob(catalogue + '/*.ini'):
        if event in str(ini_file):
            print(event + " .ini file located")
            break
    for folder in dirs:
        try:
            os.makedirs(os.path.join(event, folder))
            print(folder + " added to " + event + " directory")
        except OSError:
            print(folder + " already exists in " + event + " directory")
            pass
    with open('overview.html', 'w') as f:
        contents = """<!DOCTYPE html>
        <html>
        <head>
          <meta name="viewport" content="width=device-width, initial-scale=1">
          <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css">
          <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
          <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
        </head>

        <style>

        body {
            padding-bottom: 50px;
        }

        table {
          font-family: arial, sans-serif;
          border-collapse: collapse;
          width: 100%;
        }
        td, th {
          border: 1px solid #dddddd;
          text-align: left;
          padding: 8px;
        }

        tr:nth-child(even) {
            background-color: #dddddd;
        }

        .accordion {
            background-color: #eee;
            color: #444;
            cursor: pointer;
            padding: 2px;
            width: 100%;
            text-align: left;
            border: none;
            outline: none;
            transition: 0.4s;
        }

        .active, .accordion:hover {
            background-color: #ccc;
        }

        .panel {
            padding: 0 8px;
            background-color: white;
            display: none;
        }

        .alignleft {
                float: left;
        }
        .alignright {
                float: right;
        }
        </style>

        <div class="container">
        <h2> Setup </h2>

        <button class="accordion"> <b>The overview.html file for this run was lost.</b>
        <br> All files were lost other than the .json file and the .ini file. 
        <br> The folders and files left were created in their absence </button>
        <div class="panel">
        <table style="width:100%">

        <script>
        var acc = document.getElementsByClassName("accordion");
        var i;

        for (i = 0; i < acc.length; i++) {
            acc[i].addEventListener("click", function() {
                this.classList.toggle("active");
                var panel = this.nextElementSibling;
                if (panel.style.display === "block") {
                    panel.style.display = "none";
                } else {
                    panel.style.display = "block";
                }
            });
        }
        </script>
        """
        f.write(contents)
    shutil.move('overview.html', event + '/results_page')
    shutil.move(json_file, event + '/result')
    shutil.move(ini_file, event)
    os.rename(r + catalogue + '/' + event + '/' + ini_file, r + catalogue + '/' + event + '/' + event + '_config_complete.ini') #doesn't work
# Out:
# GWTC-2/GW190521_eccentric_merg result file located
# data added to GWTC-2/GW190521_eccentric_merg directory
# log_data_analysis added to GWTC-2/GW190521_eccentric_merg directory
# log_data_generation added to GWTC-2/GW190521_eccentric_merg directory
# log_results_page added to GWTC-2/GW190521_eccentric_merg directory
# result added to GWTC-2/GW190521_eccentric_merg directory
# results_page added to GWTC-2/GW190521_eccentric_merg directory
# submit added to GWTC-2/GW190521_eccentric_merg directory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /cvmfs/oasis.opensciencegrid.org/ligo/sw/conda/envs/igwn-py37/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     565     try:
# --> 566         os.rename(src, real_dst)
#     567     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GWTC-2/GW190521_config_complete.ini' -> 'GWTC-2/GW190521_eccentric_merg/GW190521_config_complete.ini'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-351cca5dfdca> in <module>
#     109         f.write(contents)
#     110     shutil.move('overview.html', event + '/results_page')
# --> 111     shutil.move(ini_file, event)
#     112     shutil.move(json_file, event + '/result')
#     113     os.rename(r + catalogue + '/' + event + '/' + ini_file, r + catalogue + '/' + event + '/' + event + '_config_complete.ini') #doesn't work
#
# /cvmfs/oasis.opensciencegrid.org/ligo/sw/conda/envs/igwn-py37/lib/python3.7/shutil.py in move(src, dst, copy_function)
#     578             rmtree(src)
#     579         else:
# --> 580             copy_function(src, real_dst)
#     581             os.unlink(src)
#     582     return real_dst
#
# /cvmfs/oasis.opensciencegrid.org/ligo/sw/conda/envs/igwn-py37/lib/python3.7/shutil.py in copy2(src, dst, follow_symlinks)
#     264     if os.path.isdir(dst):
#     265         dst = os.path.join(dst, os.path.basename(src))
# --> 266     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     267     copystat(src, dst, follow_symlinks=follow_symlinks)
#     268     return dst
#
# /cvmfs/oasis.opensciencegrid.org/ligo/sw/conda/envs/igwn-py37/lib/python3.7/shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'GWTC-2/GW190521_config_complete.ini'
