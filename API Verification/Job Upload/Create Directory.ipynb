# %%
import glob
import os
import shutil

catalogue = 'GWTC-2'

dirs = ['data', 'log_data_analysis', 'log_data_generation', 'log_results_page', 'result', 'results_page', 'submit']
for json_file in glob.glob(catalogue + '/*.json'):
    event = str(json_file)[:-17]
    print(event + " result file located")
    for ini_file in glob.glob(catalogue + '/*.ini'):
        if event in str(ini_file):
            print(event + " .ini file located")
            break
    for folder in dirs:
        try:
            os.makedirs(os.path.join(event, folder))
            print(folder + " added to " + event + " directory")
        except OSError:
            print(folder + " already exists in " + event + " directory")
            pass
    with open('overview.html', 'w') as f:
        contents = """<!DOCTYPE html>
        <html>
        <head>
          <meta name="viewport" content="width=device-width, initial-scale=1">
          <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css">
          <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.3.1/jquery.min.js"></script>
          <script src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
        </head>

        <style>

        body {
            padding-bottom: 50px;
        }

        table {
          font-family: arial, sans-serif;
          border-collapse: collapse;
          width: 100%;
        }
        td, th {
          border: 1px solid #dddddd;
          text-align: left;
          padding: 8px;
        }

        tr:nth-child(even) {
            background-color: #dddddd;
        }

        .accordion {
            background-color: #eee;
            color: #444;
            cursor: pointer;
            padding: 2px;
            width: 100%;
            text-align: left;
            border: none;
            outline: none;
            transition: 0.4s;
        }

        .active, .accordion:hover {
            background-color: #ccc;
        }

        .panel {
            padding: 0 8px;
            background-color: white;
            display: none;
        }

        .alignleft {
                float: left;
        }
        .alignright {
                float: right;
        }
        </style>

        <div class="container">
        <h2> Setup </h2>

        <button class="accordion"> <b>The overview.html file for this run was lost.</b>
        <br> All files were lost other than the .json file and the .ini file. 
        <br> The folders and files left were created in their absence </button>
        <div class="panel">
        <table style="width:100%">

        <script>
        var acc = document.getElementsByClassName("accordion");
        var i;

        for (i = 0; i < acc.length; i++) {
            acc[i].addEventListener("click", function() {
                this.classList.toggle("active");
                var panel = this.nextElementSibling;
                if (panel.style.display === "block") {
                    panel.style.display = "none";
                } else {
                    panel.style.display = "block";
                }
            });
        }
        </script>
        """
        f.write(contents)
    shutil.move('overview.html', event + '/results_page')
    shutil.move(json_file, event + '/result')
    shutil.move(ini_file, event)
    os.rename(r + catalogue + '/' + event + '/' + ini_file, r + catalogue + '/' + event + '/' + event + '_config_complete.ini') #doesn't work
